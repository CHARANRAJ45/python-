# %% [markdown]
# valid pallandom

# %%
class Solution:
    def isPalindrome(self, s: str) -> bool:
        l = 0
        r = len(s) - 1
        
        while l < r:
            
            while l < r and s[l].isalnum() == False: 
                l += 1
            while r > l and s[r].isalnum() == False: 
                r -= 1
            if l > r or s[l].lower() != s[r].lower():
                return False
            else:
                l += 1
                r -= 1
        return True

# %% [markdown]
# valid palindrom2

# %%
class Solution:
    def validPalindrome(self, s: str) -> bool:
        i=0
        j=len(s)-1
        while i<j:
            if s[i]!=s[j]:
                s1=s[:i]+s[i+1:]
                s2=s[:j]+s[j+1:]
                return s1==s1[::-1] or s2==s2[::-1]
            i+=1
            j-=1
        return True

# %% [markdown]
# reverse vowels leetcode:345

# %%
class Solution:
    def reverseVowels(self, s: str) -> str:
        vowels=set('aeiouAEIOU')
        s=list(s)
        i=0
        j=len(s)-1
        while i<j:
            while i<j and s[i] not in vowels:
                i+=1
            while i<j and s[j] not in vowels:
                j-=1
            s[i],s[j]=s[j],s[i]
            i+=1
            j+=1
        s=''.join(s)
        return s

# %% [markdown]
# longest palindrom or length

# %% [markdown]
# its only for odd length palindrom input

# %%
s=input("enter a valid input")
c=0
i=0
n=len(s)
j=n-1
while i<j:
    if s[i]==s[j]:
        c+=1
        i+=1
        j-=1
c=c*2+1
print(c)
# Out:
# enter a valid input abba
# 5

# %%
s=input()
if s==s[::-1]:
# Out:
#  aba
# true

# %%
s="aba"
m=0

for c in range(len(s)):
    l,r=c,c
    while l>=0 and r<len(s) and s[l]==s[r]:
        m=max(m,r-l+1)
        
        l-=1
        r+=1
    l,r=c,c+1
    while l>=0 and r<len(s) and s[l]==s[r]:
        m=max(m,r-l+1)
        
        l-=1
        r+=1
print(m,s1)
# Out:
# 3

# %% [markdown]
# longest palidogram leetcode:5

# %% [markdown]
# class Solution:
#     def longestPalindrome(self, s: str) -> str:
#         m=0
#         for i in range(len(s)):
#             r,l=i,i
#             while l>=0 and r<len(s) and s[l]==s[r]:
#                 if m<(r-l+1):
#                     m=r-l+1
#                     right=r
#                     left=l
#                 r+=1
#                 l-=1
#             r,l=i+1,i
#             while l>=0 and r<len(s) and s[l]==s[r]:
#                 if m<(r-l+1):
#                     m=r-l+1
#                     right=r
#                     left=l
#                 r+=1
#                 l-=1
#         return s[left:right+1]

# %% [markdown]
# FUNCTION IN PYTHON:
# >def is keyword used to create or define a fun

# %%
def q():
    print("hi")
    a()
def a():
    print("hello")
    q()
    
a()    
q()
# Out:
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# hi
# hello
# ...

# %%
def q(x):
    print(x,"hi")
    return 30
c=q(10) +600
print(c)
# Out:
# 10 hi
# 630

# %% [markdown]
# set path maximum limit is 1k

# %%
def q(x):
    if x==6:
        return 
    print(x)
    q(x+1)
q(1)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def sqr(n):
    print(n*n)
sqr(4)
# Out:
# 16

# %% [markdown]
# lambda fun:>
#   >when the operation if 1 we use lambda fun
# >

# %%
n=int(input())
s=lambda n:n*n
print(s(n))
# Out:
#  2
# 4

# %%
n=int(input())
m=int(input())
s=lambda a,b:a+b
print(s(n,m))
# Out:
#  2
#  7
# 9

# %% [markdown]
# filter : the fun is used to filter the values fro sequence or range like list

# %%
nums=[1,2,3,4,6,47,9,8]
evens=list(filter(lambda n:n%2==0,nums))
print(evens)
# Out:
# [2, 4, 6, 8]

# %%
def even(n):
    return n%2==0
nums=[1,3,2,5,6,7]
evens=list(filter(even,nums))
print(evens)
# Out:
# [2, 6]

# %% [markdown]
# map:performing operation on each and every data in sequence

# %%
nums=[1,2,3,4,5,6,6,7,8,10]
evens=list(filter(lambda n:n%2==0,nums))
double=list(map(lambda n:n*2,evens))
print(double)
# Out:
# [4, 8, 12, 12, 16, 20]

# %%
def up(n):
    return n*2
nums=[1,2,3,4,5,6,6,7,8,10]
evens=list(filter(lambda n:n%2==0,nums))
double=list(map(up,evens))
print(double)
# Out:
# [4, 8, 12, 12, 16, 20]

# %% [markdown]
# reduse:combine all data

# %%
from functools import reduce
def add_all(a,b):
    return a+b
nums=[1,2,3,4,5,6,6,7,8,10]
evens=list(filter(lambda n:n%2==0,nums))
double=list(map(lambda n:n*2,evens))
add=reduce(add_all,double)
print(add)
print(double)
# Out:
# 72
# [4, 8, 12, 12, 16, 20]

# %%
def even_odd(n):
    if n%2==0:
        print("even")
    else:
        print("not")
even_odd(10)
# Out:
# even

# %%
def palindrom(s):
    if s==s[::-1]:
        print(True)
    else:
        print(False)
s=input()
palindrom(s)
# Out:
#  121
# True

# %%
def sum(a,b,c):
    return a+b+c

print("sum=",sum(1,4,77))
# Out:
# sum= 82

# %%
def fibonacci_sequence(n):
    if n <= 0:
        return []
    if n == 1:
        return [0]
    fib_list = [0, 1]
    while len(fib_list) < n:
        next_fib = fib_list[-1] + fib_list[-2]
        fib_list.append(next_fib)
    return fib_list
print(fibonacci_sequence(8))
# Out:
# [0, 1, 1, 2, 3, 5, 8, 13]

# %%
def max_a(a,b,c):
    return max(a,b,c)
print("largest",max_a(20,33,55))
# Out:
# largest 55

# %%
def fact(n):
    f=1
    for i in range(1,n+1):
        f*=i
    return f
fact(6)
# Out:
# 720

# %% [markdown]
# RECURSION: there is head and tail recursion

# %%
##TAIL RECURSION
def nums(n):
    if n==0:
        return
    print(n,end=' ')
    nums(n-1)
n=int(input())
nums(n)
# Out:
#  5
# 5 4 3 2 1

# %%
#HEAD RECURSION
def nums(n):
    if n==0:
        return
    nums(n-1)
    print(n,end=' ')
    
n=int(input())
nums(n)
# Out:
#  5
# 1 2 3 4 5

# %%
def print_pattern(n):
    if n == 1:
        print(1, end="")
        return
    print(n, end="")
    print_pattern(n - 1)
    print(n, end="")

print_pattern(5)
# Out:
# 543212345

# %%
#factorial of number
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)


num = int(input("Enter a number: "))
print("Factorial:", factorial(num))
# Out:
# Enter a number:  6
# Factorial: 720

# %%
# palindrom
def palindrom(s):
    if s==s[::-1]:
        print(True)
    else:
        print(False)
s=input()
palindrom(s)
# Out:
#  121
# True

# %%
def is_perfect_square(num, i=1):
    if i * i == num:
        return True
    elif i * i > num:
        return False
    else:
        return is_perfect_square(num, i + 1)


n = int(input("Enter a number: "))
if is_perfect_square(n):
    print("Perfect square")
else:
    print("Not a perfect square")
# Out:
# Enter a number:  44
# Not a perfect square

# %%
def st(s):
    return s[::-1]
s=input()
st(s)
# Out:
#  cha
# 'ahc'

# %%
def rev_num(n,rev=0):
    if n==0:
        return rev
    return rev_num(n//10,rev*10+n%10)
n=int(input())
rev_num(n)
# Out:
#  1234
# 4321

# %%
def is_palindrom(n,rev=0,temp=None):
    if temp is None:
        temp=n
    if n==0:
        return temp==rev
    return is_palindrom(n//10,rev*10+n%10,temp)
n=int(input())
is_palindrom(n)
# Out:
#  12321
# True

# %%
def is_perfect_square(num, i=1):
    if i * i == num:
        return True
    elif i * i > num:
        return False
    else:
         return is_perfect_square(num, i + 1)
num = int(input("Enter a number: "))
is_perfect_square(num)
# Out:
# Enter a number:  44
# False

# %%
def inp(n):
    if n/2==1:
        print(False)
    else:
        inp(n/2=0)
inp(22)
# Out:
#   Cell In[3], line 5
#     inp(n/2=0)
#         ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?
